# %%
#based on the lab

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error

# %%
data = pd.read_csv("day.csv")

data = data[['yr', 'season','mnth','holiday','weekday','workingday','weathersit','temp','atemp','hum','windspeed','cnt']]

X = data.drop(columns=['cnt'])
y = data['cnt']

categorical_cols = ['season','mnth','weekday','weathersit']
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

scaler = StandardScaler()
numeric_cols = ['temp','yr','atemp','hum','windspeed','holiday','workingday']
X_encoded[numeric_cols] = scaler.fit_transform(X_encoded[numeric_cols])

X = np.asarray(X_encoded, dtype=np.float64)
y = np.asarray(y, dtype=np.float64).reshape(-1, 1)

# %%
def add_polynomial_features(X):
    return np.hstack([X, X**2])

def predict(X, w, b):
    return np.dot(X, w) + b

#based on the lab
def compute_cost(X, y, w, b, lambda_=0):
    m = X.shape[0]
    predictions = predict(X, w, b)
    # Standard MSE Cost
    cost = (1/(2*m)) * np.sum((predictions - y)**2)
    # L2 Regularization Term added (Ridge) - we do not penalize bias b
    reg_cost = (lambda_ / (2 * m)) * np.sum(w**2)
    return cost + reg_cost

#based on the lab
def compute_gradient(X, y, w, b, lambda_=0):
    m = X.shape[0]
    predictions = predict(X, w, b)
    error = predictions - y
    
    # Standard Gradients
    dj_dw = (1/m) * np.dot(X.T, error)
    dj_db = (1/m) * np.sum(error)
    
    # Add Regularization to weights (derivative of w^2 is 2w)
    dj_dw += (lambda_ / m) * w
    
    return dj_dw, dj_db

#based on the lab
def gradient_descent(X, y, w_in, b_in, alpha, num_iters, lambda_=0):
    w = w_in.copy()
    b = b_in
    J_history = []
    
    for i in range(num_iters):
        dj_dw, dj_db = compute_gradient(X, y, w, b, lambda_)
        w -= alpha * dj_dw
        b -= alpha * dj_db
        
        # Save cost for plotting (Training Cost)
        if i % 100 == 0: # Record every 100th iteration to speed up
            cost = compute_cost(X, y, w, b, lambda_)
            J_history.append(cost)         
            
    return w, b, J_history

# %%
# Add polynomial features (x^2)
X = add_polynomial_features(X)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
alpha = 0.05       # Adjusted learning rate
iterations = 2000  # Increased iterations for convergence
lambda_val = 0.5   # Regularization strength

r2_scores, rmse_scores, mae_scores = [], [], []
fold = 1

# Store data for final plots (from the last fold)
final_y_test = None
final_y_pred = None
final_J_hist = None

print("Starting 5-Fold Cross-Validation with Regularization...")

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # Flatten y to ensure shapes match (m,) instead of (m,1)
    y_train = y_train.ravel()
    y_test = y_test.ravel()
    
    n = X_train.shape[1]
    w = np.zeros(n) 
    b = 0.0

    # Train with L2 Regularization
    w, b, J_hist = gradient_descent(X_train, y_train, w, b, alpha, iterations, lambda_=lambda_val)
    
    # Predict on Test Set
    y_pred = predict(X_test, w, b)

    # Calculate Metrics
    r2 = r2_score(y_test, y_pred)
    rmse = root_mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    print(f"Fold {fold}: R²={r2:.3f}, RMSE={rmse:.2f}, MAE={mae:.2f}")
    r2_scores.append(r2)
    rmse_scores.append(rmse)
    mae_scores.append(mae)
    
    # Save last fold data for visualization
    final_y_test = y_test
    final_y_pred = y_pred
    final_J_hist = J_hist
    fold += 1

print("\n=== Average Model Performance (Linear Regression + L2 Regularization) ===")
print(f"Average R²   : {np.mean(r2_scores):.3f} ± {np.std(r2_scores):.3f}")
print(f"Average RMSE : {np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}")
print(f"Average MAE  : {np.mean(mae_scores):.2f} ± {np.std(mae_scores):.2f}")


# Plot 1: Actual vs Predicted (Test Data)
plt.figure(figsize=(12,5))
plt.plot(final_y_test[:100], label="Actual (Test)", color='blue')
plt.plot(final_y_pred[:100], label="Predicted (Test)", color='red', alpha=0.7)
plt.title("Actual vs Predicted Bike Rentals (Test Set - Fold 5)")
plt.xlabel("Sample index")
plt.ylabel("Number of rented bikes")
plt.legend()
plt.grid(True)
plt.show()

# Plot 2: Scatter Plot (Test Data)
plt.figure(figsize=(6,6))
sns.scatterplot(x=final_y_test, y=final_y_pred, alpha=0.5)
plt.plot([0, np.max(final_y_test)], [0, np.max(final_y_test)], '--', color='red', label="Perfect Prediction")
plt.xlabel("Actual Rentals")
plt.ylabel("Predicted Rentals")
plt.title("Predicted vs Actual Scatterplot (Test Set)")
plt.grid(True)
plt.show()

# Plot 3: Cost Function (Training Data)
plt.figure(figsize=(8,5))
plt.plot(range(0, iterations, 100), final_J_hist)
plt.title("Training Cost Function (Convergence Check)")
plt.xlabel("Iterations (x10)")
plt.ylabel("Cost J(w,b)")
plt.grid(True)
plt.show()
# Out:
# Starting 5-Fold Cross-Validation with Regularization...
# Fold 1: R²=0.867, RMSE=731.40, MAE=533.36
# Fold 2: R²=0.861, RMSE=711.79, MAE=539.57
# Fold 3: R²=0.855, RMSE=741.37, MAE=529.91
# Fold 4: R²=0.795, RMSE=800.76, MAE=558.33
# Fold 5: R²=0.885, RMSE=674.08, MAE=545.37
#
# === Average Model Performance (Linear Regression + L2 Regularization) ===
# Average R²   : 0.852 ± 0.030
# Average RMSE : 731.88 ± 41.42
# Average MAE  : 541.31 ± 10.02
